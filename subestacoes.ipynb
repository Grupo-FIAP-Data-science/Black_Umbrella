# %%
import geopandas as gpd

# %%
gpd = gpd.read_file('dados/subestacoes/Subestações_-_Base_Existente.shp')

# %%
gpd
# Out:
#                          Nome  \
# 0               SE Anhanguera
# 1             SE Bandeirantes
# 2             SE Centro - CTR
# 3             SE Centro - CTT
# 4               SE Interlagos
# 5             SE Miguel Reale
# 6         SE Milton Fornasaro
# 7                    SE Norte
# 8              SE Piratininga
# 9            SE Piratininga 2
# 10                SE Pirituba
# 11     SE Ramom Reberte Filho
# 12                     SE Sul
# 13                   SE Leste
# 14                SE Xavantes
# 15  SE UTE Fernando Gasparian
# 16         SE UTE Piratininga
#
#                                            Concession Ano_Opera       Tensao  \
# 0   CTEEP - Companhia de Transmissão de Energia El...         -   345/230/88
# 1   CTEEP - Companhia de Transmissão de Energia El...         -  345/88/34,5
# 2   CTEEP - Companhia de Transmissão de Energia El...         -    230/88/20
# 3   CTEEP - Companhia de Transmissão de Energia El...         -          230
# ...
