# %% [markdown]
# ### Notebook criado para obter o distrito de cada ocorrência

# %%
import geopandas as gpd
import re
from pyproj import Proj, Transformer
import pandas as pd

# %%
# Lista com os anos dos arquivos
lista_anos = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
dataframes = {}

# Percorrendo a lista e carregando os DataFrames
for ano in lista_anos:
    arquivo = f'../dados/ocorrencias/SIRGAS_SHP_riscoocorrencia_{ano}.shp'
    dataframes[f'df_{ano}'] = gpd.read_file(arquivo)

df_2013 = dataframes['df_2013']
df_2014 = dataframes['df_2014']
df_2015 = dataframes['df_2015']
df_2016 = dataframes['df_2016']
df_2017 = dataframes['df_2017']
df_2018 = dataframes['df_2018']
df_2019 = dataframes['df_2019']
df_2020 = dataframes['df_2020']
df_2021 = dataframes['df_2021']
df_2022 = dataframes['df_2022']
df_2023 = dataframes['df_2023']
df_2024 = dataframes['df_2024']

# %%
df_total1 = pd.concat([df_2021, df_2022, df_2023, df_2024], ignore_index=True)
df_total2 = pd.concat([df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020], ignore_index=True)

df_total1 = df_total1.rename(columns={'subpreit':'subprefeit'})

df_total = pd.concat([df_total2, df_total1], ignore_index=True)

# %%
df_total
# Out:
#                       data       ocorrencia              subprefeit      name  \
# 0      2013-12-29 00:00:00  QUEDA DE ARVORE            BT - BUTANTA     47368
# 1      2013-12-03 00:00:00  QUEDA DE ARVORE  CS - CAPELA DO SOCORRO     45006
# 2      2013-12-10 00:00:00       ALAGAMENTO        SA - SANTO AMARO     45361
# 3      2013-12-30 00:00:00  QUEDA DE ARVORE                 SE - SE     47427
# 4      2013-12-29 00:00:00  QUEDA DE ARVORE        SA - SANTO AMARO     47337
# ...                    ...              ...                     ...       ...
# 58267  2024-01-31 00:00:00       ALAGAMENTO          SB - SAPOPEMBA  32057914
# 58268  2024-01-31 00:00:00  QUEDA DE ARVORE           IQ - ITAQUERA  32058056
# 58269  2024-01-31 00:00:00        INUNDACAO  CS - CAPELA DO SOCORRO  32058336
# 58270  2024-01-31 00:00:00  QUEDA DE ARVORE            BT - BUTANTA  32058368
# 58271  2024-01-31 00:00:00  QUEDA DE ARVORE      VP - VILA PRUDENTE  32058474
#
#                                  geometry
# 0      POINT Z (318923.714 7389107.424 0)
# 1       POINT Z (326291.01 7378438.554 0)
# 2       POINT Z (325784.879 7383070.03 0)
# 3      POINT Z (332913.137 7396238.346 0)
# 4      POINT Z (325940.608 7385402.683 0)
# ...                                   ...
# 58267      POINT (347483.632 7386553.452)
# 58268      POINT (354127.126 7394828.661)
# 58269      POINT (328375.103 7375680.959)
# 58270      POINT (324562.933 7390714.965)
# 58271       POINT (341353.971 7388732.52)
#
# [58272 rows x 5 columns]

# %%
gdf = gpd.read_file('../dados/distritos_shapefile/SIRGAS_SHP_distrito.shp')

# %%
gdf
# Out:
#             ds_nome ds_codigo ds_cd_sub        ds_subpref ds_sigla  \
# 0          MANDAQUI        51        05  SANTANA-TUCURUVI      MAN
# 1          MARSILAC        52        20       PARELHEIROS      MAR
# 2             MOEMA        32        12      VILA MARIANA      MOE
# 3       ARTUR ALVIM         5        21             PENHA      AAL
# 4          IGUATEMI        33        30        SAO MATEUS      IGU
# ..              ...       ...       ...               ...      ...
# 91      CAMPO LIMPO        17        17       CAMPO LIMPO      CLM
# 92          JAGUARE        41        08              LAPA      JRE
# 93          JARAGUA        42        02  PIRITUBA-JARAGUA      JAR
# 94    JARDIM HELENA        44        23        SAO MIGUEL      JDH
# 95  JARDIM PAULISTA        45        11         PINHEIROS      JDP
#
#        ds_areamt  ds_areakm                                           geometry
# 0   1.324786e+07     13.248  POLYGON ((330950.373 7407837.176, 330952.177 7...
# 1   2.081957e+08    208.196  POLYGON ((336124.09 7355302.282, 336121.755 73...
# 2   9.079516e+06      9.080  POLYGON ((331242.174 7392162.324, 331244.581 7...
# 3   6.508361e+06      6.508  POLYGON ((349416.226 7397718.808, 349416.884 7...
# 4   1.958356e+07     19.584  POLYGON ((350859.949 7389599.855, 350880.182 7...
# ..           ...        ...                                                ...
# 91  1.259634e+07     12.596  POLYGON ((321265.375 7388006.57, 321292.309 73...
# 92  6.579876e+06      6.580  POLYGON ((322952.516 7394978.618, 323250.62 73...
# 93  2.833031e+07     28.330  POLYGON ((319172.403 7405179.204, 319174.204 7...
# 94  9.148559e+06      9.149  POLYGON ((352915.621 7402621.049, 352944.248 7...
# 95  6.186611e+06      6.187  POLYGON ((329605.461 7390837.489, 329600.764 7...
#
# [96 rows x 8 columns]

# %%
# Realizando a junção espacial entre os DataFrames de acordo com a localização
gdf_ocorrencias_com_distritos = gpd.sjoin(df_total, gdf, how="left", predicate="within")

# %%
gdf_ocorrencias_com_distritos
# Out:
#                       data       ocorrencia              subprefeit      name  \
# 0      2013-12-29 00:00:00  QUEDA DE ARVORE            BT - BUTANTA     47368
# 1      2013-12-03 00:00:00  QUEDA DE ARVORE  CS - CAPELA DO SOCORRO     45006
# 2      2013-12-10 00:00:00       ALAGAMENTO        SA - SANTO AMARO     45361
# 3      2013-12-30 00:00:00  QUEDA DE ARVORE                 SE - SE     47427
# 4      2013-12-29 00:00:00  QUEDA DE ARVORE        SA - SANTO AMARO     47337
# ...                    ...              ...                     ...       ...
# 58267  2024-01-31 00:00:00       ALAGAMENTO          SB - SAPOPEMBA  32057914
# 58268  2024-01-31 00:00:00  QUEDA DE ARVORE           IQ - ITAQUERA  32058056
# 58269  2024-01-31 00:00:00        INUNDACAO  CS - CAPELA DO SOCORRO  32058336
# 58270  2024-01-31 00:00:00  QUEDA DE ARVORE            BT - BUTANTA  32058368
# 58271  2024-01-31 00:00:00  QUEDA DE ARVORE      VP - VILA PRUDENTE  32058474
#
#                                  geometry  index_right         ds_nome  \
# 0      POINT Z (318923.714 7389107.424 0)         19.0  RAPOSO TAVARES
# 1       POINT Z (326291.01 7378438.554 0)         63.0         SOCORRO
# 2       POINT Z (325784.879 7383070.03 0)         60.0     SANTO AMARO
# 3      POINT Z (332913.137 7396238.346 0)         55.0       REPUBLICA
# 4      POINT Z (325940.608 7385402.683 0)         60.0     SANTO AMARO
# ...                                   ...          ...             ...
# 58267      POINT (347483.632 7386553.452)         22.0       SAPOPEMBA
# 58268      POINT (354127.126 7394828.661)          9.0  JOSE BONIFACIO
# 58269      POINT (328375.103 7375680.959)         40.0    CIDADE DUTRA
# 58270      POINT (324562.933 7390714.965)         87.0         BUTANTA
# 58271       POINT (341353.971 7388732.52)         74.0   VILA PRUDENTE
#
#       ds_codigo ds_cd_sub         ds_subpref ds_sigla    ds_areamt  ds_areakm
# 0            65        10            BUTANTA      RTA  12433885.23     12.434
# 1            79        19  CAPELA DO SOCORRO      SOC  11965477.82     11.965
# 2            71        14        SANTO AMARO      SAM  16036225.98     16.036
# 3            66        09                 SE      REP   2396993.44      2.397
# 4            71        14        SANTO AMARO      SAM  16036225.98     16.036
# ...         ...       ...                ...      ...          ...        ...
# 58267        76        32          SAPOPEMBA      SAP  13631253.32     13.631
# 58268        47        27           ITAQUERA      JBO  14566043.13     14.566
# 58269        23        19  CAPELA DO SOCORRO      CDU  27965809.76     27.966
# 58270        12        10            BUTANTA      BUT  12952409.83     12.952
# 58271        93        29      VILA PRUDENTE      VPR   9584953.30      9.585
#
# [58272 rows x 13 columns]

# %%
base_final = gdf_ocorrencias_com_distritos.drop(columns=['name', 'index_right', 'ds_codigo', 'ds_cd_sub', 'ds_sigla', 'ds_areamt','ds_areakm', 'ds_subpref'])

# %%
base_final
# Out:
#                       data       ocorrencia              subprefeit  \
# 0      2013-12-29 00:00:00  QUEDA DE ARVORE            BT - BUTANTA
# 1      2013-12-03 00:00:00  QUEDA DE ARVORE  CS - CAPELA DO SOCORRO
# 2      2013-12-10 00:00:00       ALAGAMENTO        SA - SANTO AMARO
# 3      2013-12-30 00:00:00  QUEDA DE ARVORE                 SE - SE
# 4      2013-12-29 00:00:00  QUEDA DE ARVORE        SA - SANTO AMARO
# ...                    ...              ...                     ...
# 58267  2024-01-31 00:00:00       ALAGAMENTO          SB - SAPOPEMBA
# 58268  2024-01-31 00:00:00  QUEDA DE ARVORE           IQ - ITAQUERA
# 58269  2024-01-31 00:00:00        INUNDACAO  CS - CAPELA DO SOCORRO
# 58270  2024-01-31 00:00:00  QUEDA DE ARVORE            BT - BUTANTA
# 58271  2024-01-31 00:00:00  QUEDA DE ARVORE      VP - VILA PRUDENTE
#
#                                  geometry         ds_nome
# 0      POINT Z (318923.714 7389107.424 0)  RAPOSO TAVARES
# 1       POINT Z (326291.01 7378438.554 0)         SOCORRO
# 2       POINT Z (325784.879 7383070.03 0)     SANTO AMARO
# 3      POINT Z (332913.137 7396238.346 0)       REPUBLICA
# 4      POINT Z (325940.608 7385402.683 0)     SANTO AMARO
# ...                                   ...             ...
# 58267      POINT (347483.632 7386553.452)       SAPOPEMBA
# 58268      POINT (354127.126 7394828.661)  JOSE BONIFACIO
# 58269      POINT (328375.103 7375680.959)    CIDADE DUTRA
# 58270      POINT (324562.933 7390714.965)         BUTANTA
# 58271       POINT (341353.971 7388732.52)   VILA PRUDENTE
#
# [58272 rows x 5 columns]

# %%
df = base_final.copy()

# %%
df['geometry'] = df['geometry'].astype(str)
# Out:
# C:\Users\prado\AppData\Local\Temp\ipykernel_31196\1692990100.py:1: UserWarning: Geometry column does not contain geometry.
#   df['geometry'] = df['geometry'].astype(str)

# %%
# Definindo o sistema de coordenadas UTM zona 23S
utm_proj_2d = Proj(proj='utm', zone=23, south=True, ellps='WGS84')
utm_proj_3d = Proj(proj='utm', zone=23, south=True, ellps='WGS84', datum='WGS84')
wgs84_proj = Proj(proj='latlong', datum='WGS84')

transformer_2d = Transformer.from_proj(utm_proj_2d, wgs84_proj)
transformer_3d = Transformer.from_proj(utm_proj_3d, wgs84_proj)

def converte_para_latlon(point_str):
    # Detectar se é POINT Z ou POINT
    if 'POINT Z' in point_str:
        # Extrair as coordenadas do formato POINT Z
        parts = point_str.replace('POINT Z (', '').replace(')', '').split()
        x, y = float(parts[0]), float(parts[1])
        # Converter coordenadas UTM 3D para latitude e longitude
        lat, lon = transformer_3d.transform(x, y)
    elif 'POINT' in point_str:
        # Extrair as coordenadas do formato POINT
        parts = point_str.replace('POINT (', '').replace(')', '').split()
        x, y = float(parts[0]), float(parts[1])
        # Converter coordenadas UTM 2D para latitude e longitude
        lat, lon = transformer_2d.transform(x, y)
    else:
        # Caso não seja um formato reconhecido
        return None, None
    return lat, lon

# Aplicar a função para criar as novas colunas 'Latitude' e 'Longitude'
df[['Longitude', 'Latitude']] = df['geometry'].apply(lambda x: pd.Series(converte_para_latlon(x)))

# Exibindo o DataFrame atualizado
df
# Out:
#                       data       ocorrencia              subprefeit  \
# 0      2013-12-29 00:00:00  QUEDA DE ARVORE            BT - BUTANTA
# 1      2013-12-03 00:00:00  QUEDA DE ARVORE  CS - CAPELA DO SOCORRO
# 2      2013-12-10 00:00:00       ALAGAMENTO        SA - SANTO AMARO
# 3      2013-12-30 00:00:00  QUEDA DE ARVORE                 SE - SE
# 4      2013-12-29 00:00:00  QUEDA DE ARVORE        SA - SANTO AMARO
# ...                    ...              ...                     ...
# 58267  2024-01-31 00:00:00       ALAGAMENTO          SB - SAPOPEMBA
# 58268  2024-01-31 00:00:00  QUEDA DE ARVORE           IQ - ITAQUERA
# 58269  2024-01-31 00:00:00        INUNDACAO  CS - CAPELA DO SOCORRO
# 58270  2024-01-31 00:00:00  QUEDA DE ARVORE            BT - BUTANTA
# 58271  2024-01-31 00:00:00  QUEDA DE ARVORE      VP - VILA PRUDENTE
#
#                                        geometry         ds_nome  Longitude  \
# 0        POINT Z (318923.7137 7389107.424428 0)  RAPOSO TAVARES -46.774643
# 1      POINT Z (326291.010146 7378438.554415 0)         SOCORRO -46.703712
# 2      POINT Z (325784.879025 7383070.030225 0)     SANTO AMARO -46.708130
# 3      POINT Z (332913.137082 7396238.345912 0)       REPUBLICA -46.636786
# 4      POINT Z (325940.608356 7385402.683087 0)     SANTO AMARO -46.706331
# ...                                         ...             ...        ...
# 58267      POINT (347483.631646 7386553.451906)       SAPOPEMBA -46.495083
# 58268        POINT (354127.125688 7394828.6609)  JOSE BONIFACIO -46.429165
# 58269      POINT (328375.102682 7375680.958842)    CIDADE DUTRA -46.683598
# 58270      POINT (324562.933229 7390714.964635)         BUTANTA -46.719206
# 58271       POINT (341353.97062 7388732.519519)   VILA PRUDENTE -46.554922
#
#         Latitude
# 0     -23.598443
# 1     -23.695577
# 2     -23.653706
# 3     -23.535563
# 4     -23.632662
# ...          ...
# 58267 -23.624450
# 58268 -23.550340
# 58269 -23.720698
# 58270 -23.584550
# 58271 -23.604184
#
# [58272 rows x 7 columns]

# %%
df.to_csv('../dados/ocorrencias_com_distritos.csv', index=False)

# %%
df_aws = pd.read_csv('../dados/ocorrencias_com_distritos.csv', sep=',')

# %%
df_aws
# Out:
#              data         data_hora       ocorrencia              subprefeit  \
# 0      29/12/2013  29/12/2013 00:00  QUEDA DE ARVORE            BT - BUTANTA
# 1      03/12/2013  03/12/2013 00:00  QUEDA DE ARVORE  CS - CAPELA DO SOCORRO
# 2      10/12/2013  10/12/2013 00:00       ALAGAMENTO        SA - SANTO AMARO
# 3      30/12/2013  30/12/2013 00:00  QUEDA DE ARVORE                 SE - SE
# 4      29/12/2013  29/12/2013 00:00  QUEDA DE ARVORE        SA - SANTO AMARO
# ...           ...               ...              ...                     ...
# 58267  31/01/2024  31/01/2024 00:00       ALAGAMENTO          SB - SAPOPEMBA
# 58268  31/01/2024  31/01/2024 00:00  QUEDA DE ARVORE           IQ - ITAQUERA
# 58269  31/01/2024  31/01/2024 00:00        INUNDACAO  CS - CAPELA DO SOCORRO
# 58270  31/01/2024  31/01/2024 00:00  QUEDA DE ARVORE            BT - BUTANTA
# 58271  31/01/2024  31/01/2024 00:00  QUEDA DE ARVORE      VP - VILA PRUDENTE
#
#                                        geometry         ds_nome  \
# 0        POINT Z (318923.7137 7389107.424428 0)  RAPOSO TAVARES
# 1      POINT Z (326291.010146 7378438.554415 0)         SOCORRO
# 2      POINT Z (325784.879025 7383070.030225 0)     SANTO AMARO
# 3      POINT Z (332913.137082 7396238.345912 0)       REPUBLICA
# 4      POINT Z (325940.608356 7385402.683087 0)     SANTO AMARO
# ...                                         ...             ...
# 58267      POINT (347483.631646 7386553.451906)       SAPOPEMBA
# 58268        POINT (354127.125688 7394828.6609)  JOSE BONIFACIO
# 58269      POINT (328375.102682 7375680.958842)    CIDADE DUTRA
# 58270      POINT (324562.933229 7390714.964635)         BUTANTA
# 58271       POINT (341353.97062 7388732.519519)   VILA PRUDENTE
#
#                      Longitude                 Latitude
# 0       -4.677.464.276.631.380  -23.598.442.687.972.200
# 1       -4.670.371.173.463.540  -23.695.576.883.145.000
# 2       -4.670.813.032.481.320  -23.653.706.273.415.000
# 3      -46.636.786.132.214.800  -23.535.563.110.036.600
# 4      -46.706.330.823.636.300   -2.363.266.230.962.370
# ...                        ...                      ...
# 58267   -4.649.508.310.000.040   -2.362.445.049.928.760
# 58268   -4.642.916.489.999.810  -23.550.339.599.290.200
# 58269   -4.668.359.769.999.980  -23.720.697.999.281.000
# 58270  -46.719.205.899.991.200   -2.358.455.039.929.060
# 58271   -4.655.492.169.999.460   -2.360.418.429.928.150
#
# [58272 rows x 8 columns]

# %%
import pandas as pd
import boto3
import os
from dotenv import load_dotenv
from io import StringIO

# %%
# Função para enviar para o S3
def upload_to_s3(df):
    # Configurações do S3
    access_key_id = os.getenv("AWS_ACCESS_KEY_ID")
    secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY")

    s3 = boto3.client('s3',
                  aws_access_key_id=access_key_id,
                  aws_secret_access_key=secret_access_key,
                  region_name = 'sa-east-1')

    # Carregar o arquivo CSV para o S3
    s3.put_object(Bucket='black-umbrella-fiap',
                Key='bronze/ocorrencias/ocorrencias_com_distritos.csv',
                Body=df.getvalue())
    
    print('Arquivo enviado para o S3 com sucesso!')

# %%
csv_buffer = StringIO()
df_aws.to_csv(csv_buffer, index=False)
# Enviar os arquivos particionados para o S3
upload_to_s3(csv_buffer)
# Out:
# Arquivo enviado para o S3 com sucesso!
