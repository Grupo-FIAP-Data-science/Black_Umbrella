# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/prado/Downloads/interrupcoes-energia-eletrica-2024.csv', encoding='latin1', sep=';')
# Out:
# C:\Users\prado\AppData\Local\Temp\ipykernel_23416\489810114.py:1: DtypeWarning: Columns (3,5,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/prado/Downloads/interrupcoes-energia-eletrica-2024.csv', encoding='latin1', sep=';')

# %%
df
# Out:
#         DatGeracaoConjuntoDados  IdeConjuntoUnidadeConsumidora  \
# 25                   2024-08-10                        12595.0
# 26                   2024-08-10                        12595.0
# 27                   2024-08-10                        12598.0
# 28                   2024-08-10                        17306.0
# 29                   2024-08-10                        17310.0
# ...                         ...                            ...
# 4601168              2024-08-10                        12581.0
# 4601169              2024-08-10                        13004.0
# 4601170              2024-08-10                        12581.0
# 4601171              2024-08-10                        12581.0
# 4601172              2024-08-10                        13008.0
#
#         DscConjuntoUnidadeConsumidora DscAlimentadorSubestacao  \
# 25                    Cruzeiro do Sul                     01C1
# 26                    Cruzeiro do Sul                     01C1
# ...

# %%
df['NomAgenteRegulado'].unique
# Out:
# <bound method Series.unique of 0                         Não Informado
# 1                        Não Encontrado
# 2                         Não se Aplica
# 3               CMI Power Amazonas Ltda
# 4             Banakoba - Banakoba  LTDA
#                        ...
# 4618204                 EVERSON VINKLER
# 4618205              ARTHUR NAHAS NEVES
# 4618206        JULIANA BRUNINI BOMTEMPO
# 4618207           ROBINSON PERCY HOLDER
# 4618208    B2 INDUSTRIA E COMERCIO LTDA
# Name: NomAgenteRegulado, Length: 4618209, dtype: object>

# %%
df['DatInicioInterrupcao'].isnull().sum()
# Out:
# 0

# %%
df.dropna(subset=['DatInicioInterrupcao'], inplace=True)

# %%
df['DscConjuntoUnidadeConsumidora'].value_counts()
# Out:
# DscConjuntoUnidadeConsumidora
# MÉDIO E BAIXO AMAZONAS        14718
# SÃO PEDRO                     11017
# RIO NEGRO E BAIXO SOLIMÕES    10962
# PINHEIROS                      9765
# SANTO ANTÔNIO                  9648
#                               ...
# BANDEIRANTES_RETICULADO          23
# AVEIRO                           22
# PARAGOMINAS III                   1
# VOTUPORANGA                       1
# Ji-Parana                         1
# Name: count, Length: 2959, dtype: int64
