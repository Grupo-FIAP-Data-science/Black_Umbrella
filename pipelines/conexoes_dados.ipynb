# %%
import folium

# Crie o mapa centrado em São Paulo
mapa = folium.Map(location=[-23.55052, -46.633308], zoom_start=12)

# Exiba o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Lista de coordenadas (latitude, longitude)
localizacoes = [
    {'nome': 'Local 1', 'latitude': 33.739132, 'longitude': 73.8762065}
]

# Adicione marcadores ao mapa
for local in localizacoes:
    folium.Marker(
        location=[local['latitude'], local['longitude']],
        popup=local['nome'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mapa)

# Exiba o mapa com os marcadores
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium import plugins

# Crie o mapa centrado em São Paulo
mapa = folium.Map(location=[-23.55052, -46.633308], zoom_start=12)

# Adiciona uma função de clique ao mapa
mapa.add_child(folium.LatLngPopup())

# JavaScript para adicionar marcador em cliques
click_js = """
function(e) {
    var lat = e.latlng.lat;
    var lon = e.latlng.lng;
    var marker = L.marker([lat, lon]).addTo(mapa);
    marker.bindPopup('Latitude: ' + lat + '<br>Longitude: ' + lon).openPopup();
}
"""

# Vincular o evento de clique ao JavaScript
mapa.add_child(folium.ClickForMarker(popup=None))

# Adicionando o script ao mapa
mapa.add_child(folium.GeoJson(data={}, name='geojson').add_child(folium.Element('<script>' + click_js + '</script>')))

# Exibe o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Crie o mapa centrado em São Paulo
mapa = folium.Map(location=[-23.55052, -46.633308], zoom_start=12)

# JavaScript para gerenciar o clique no mapa e exibir as informações da região
click_js = """
    var popup = L.popup();
    function onMapClick(e) {
        // Fechar o popup anterior (se existir)
        if (popup) {
            mapa.closePopup(popup);
        }

        // Coletar informações fictícias da região (você pode integrar APIs para obter informações reais)
        var info = "Informações da região: " + e.latlng.lat.toFixed(5) + ", " + e.latlng.lng.toFixed(5);

        // Criar um novo popup com as informações da região
        popup
            .setLatLng(e.latlng)
            .setContent(info)
            .openOn(mapa);
    }

    // Vincular o evento de clique no mapa à função onMapClick
    mapa.on('click', onMapClick);
"""

# Adicionar o script JavaScript ao mapa
mapa.get_root().html.add_child(folium.Element(f'<script>{click_js}</script>'))

# Exibir o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Coordenadas aproximadas do centro de São Paulo
latitude_sao_paulo = -23.55052
longitude_sao_paulo = -46.633308

# Definir os limites do mapa (bounding box) para cobrir a área da cidade de São Paulo
bounds = [[-23.7333, -46.8256], [-23.4733, -46.4194]]

# Criar o mapa centralizado em São Paulo com os limites definidos
mapa = folium.Map(
    location=[latitude_sao_paulo, longitude_sao_paulo],
    zoom_start=12,
    min_zoom=10,
    max_bounds=True
)

# Definir os limites de exibição do mapa
mapa.fit_bounds(bounds)

# Exibir o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

# Coordenadas aproximadas do centro de São Paulo
latitude_sao_paulo = -23.55052
longitude_sao_paulo = -46.633308

# Definir os limites do mapa (bounding box) para cobrir a área da cidade de São Paulo
# Esses limites são aproximados e podem ser ajustados conforme necessário
bounds = [[-23.744, -46.8256], [-23.4733, -46.4194]]

# Criar o mapa centralizado em São Paulo com os limites definidos
mapa = folium.Map(
    location=[latitude_sao_paulo, longitude_sao_paulo],
    zoom_start=12,
    max_bounds=True,  # Mantém o mapa dentro dos limites definidos
)

# Ajustar os limites do mapa para a área de São Paulo
mapa.fit_bounds(bounds)

# Exibir o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd

df = pd.read_html('https://www.cgesp.org/v3/estacao.jsp?POSTO=1000850')

df_1 = df[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 5
#       1 import pandas as pd
#       3 df = pd.read_html('https://www.cgesp.org/v3/estacao.jsp?POSTO=1000850')
# ----> 5 df_1 = df[6]
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup

# URL da página
url = "https://www.cgesp.org/v3/estacao.jsp?POSTO=1000850"

# Realiza a requisição à página
response = requests.get(url)

# Verifica se a requisição foi bem-sucedida
if response.status_code == 200:
    # Faz o parse do conteúdo HTML
    soup = BeautifulSoup(response.content, 'lxml')
    
    # Encontra a tabela usando XPath
    # No caso do BeautifulSoup, não há suporte direto para XPath, então precisamos encontrar a tabela de outra forma
    tables = soup.find_all('table')
    # Verifica se há duas tabelas (baseado no XPath fornecido)
    if len(tables) > 1:
        table = tables[2]  # Seleciona a segunda tabela

        # Inicializa uma lista para armazenar os dados
        data = []

        # Itera sobre as linhas da tabela
        for row in table.find_all('tr'):
            cols = row.find_all('td')
            cols = [col.text.strip() for col in cols]
            data.append(cols)
        
        # Exibe os dados
        for row in data:
            print(row)
    else:
        print("Tabela não encontrada no XPath especificado.")
else:
    print(f"Erro ao acessar a página: {response.status_code}")
# Out:
# ['Atual:', '19.7 ºC']
# ['Máxima:', '24.8 ºC']
# ['Mínima:', '13.0 ºC']

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# Inicializa o WebDriver do Edge
driver = webdriver.Edge()

# URL da página
url = "https://www.cgesp.org/v3/estacao.jsp?POSTO=1000850"
driver.get(url)

# Alterna o foco para o iframe (assumindo que o iframe é o primeiro da página)
iframe = driver.find_element(By.TAG_NAME, 'iframe')
driver.switch_to.frame(iframe)

# Agora localize a tabela usando o XPath
table = driver.find_element(By.XPATH, '/html/body/table/tbody')

# Inicializa uma lista para armazenar os dados
data = []

# Itera sobre as linhas da tabela
rows = table.find_elements(By.TAG_NAME, 'tr')
for row in rows:
    cols = row.find_elements(By.TAG_NAME, 'td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)

# Fecha o navegador
driver.quit()

# Converte para DataFrame do pandas
df = pd.DataFrame(data)

# Exibe o DataFrame
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]
